# %%
import pandas as pd
import numpy as np
import igraph as ig
import matplotlib.pyplot as plt

# %%
df_unweighted = pd.read_csv('../combined_final_unweighted.csv')
df_unweighted
# Out:
#           node_start                node_end        status
# 0          Hong Kong                   Samoa  jurisdiction
# 1          Hong Kong                   Samoa  jurisdiction
# 2          Hong Kong                   Samoa  jurisdiction
# 3          Hong Kong                   Samoa  jurisdiction
# 4          Hong Kong                   Samoa  jurisdiction
# ...              ...                     ...           ...
# 338127     Indonesia  British Virgin Islands  officer_base
# 338128  Cook Islands  British Virgin Islands  officer_base
# 338129     Hong Kong  British Virgin Islands  officer_base
# 338130  Cook Islands          United Kingdom  officer_base
# 338131     Hong Kong          United Kingdom  officer_base
#
# [338132 rows x 3 columns]

# %%
df_weighted = pd.read_csv('../combined_final_weighted.csv')
df_weighted
# Out:
#           node_start                node_end        status  weight
# 0          Hong Kong                   Samoa  jurisdiction     2.0
# 1          Hong Kong                   Samoa  jurisdiction     2.0
# 2          Hong Kong                   Samoa  jurisdiction     2.0
# 3          Hong Kong                   Samoa  jurisdiction     2.0
# 4          Hong Kong                   Samoa  jurisdiction     2.0
# ...              ...                     ...           ...     ...
# 338119     Indonesia  British Virgin Islands  officer_base     1.0
# 338120  Cook Islands  British Virgin Islands  officer_base     1.0
# 338121     Hong Kong  British Virgin Islands  officer_base     1.0
# 338122  Cook Islands          United Kingdom  officer_base     1.0
# 338123     Hong Kong          United Kingdom  officer_base     1.0
#
# [338124 rows x 4 columns]

# %%
df_dir = pd.read_csv('../combined_final_weighted_groupedby.csv')
df_dir
# Out:
#      node_start                node_end  weight
# 0       Albania                 Bahamas     4.0
# 1       Algeria  British Virgin Islands     2.0
# 2       Algeria          United Kingdom     2.0
# 3       Algeria           United States     1.0
# 4       Andorra                 Bahamas    52.0
# ...         ...                     ...     ...
# 2835   Zimbabwe               Hong Kong     3.0
# 2836   Zimbabwe                  Jersey     1.0
# 2837   Zimbabwe                  Panama     6.0
# 2838   Zimbabwe                  Russia     2.0
# 2839   Zimbabwe           United States     1.0
#
# [2840 rows x 3 columns]

# %%
#plot the unweighted graph (try unweighted first)
g = ig.Graph.TupleList(df_dir.itertuples(index=False), directed=True, edge_attrs={'weight': "weight"})

# %%
ig.plot(g)

# %%
g.diameter()
# Out:
# 4

# %%
len(g.vs.indices)
# Out:
# 196

# %%
#g.vs.indices
df_dir['node_start'].value_counts()
# Out:
# Hong Kong                     60
# United States                 55
# Taiwan                        53
# China                         53
# Singapore                     52
#                               ..
# Sudan                          1
# Norfolk Island                 1
# Albania                        1
# Saint Martin (French part)     1
# Yemen                          1
# Name: node_start, Length: 190, dtype: int64

# %%
uni =df_dir['node_start'].unique()

# %%
len(uni)
# Out:
# 190

# %%
list(g.vs)
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 0, {'name': 'Albania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 2, {'name': 'Algeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 6, {'name': 'Andorra'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 9, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 19, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 20, {'name': 'Angola'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 23, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 27, {'name': 'Argentina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 28, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 29, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 30, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 31, {'name': 'Armenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 32, {'name': 'Aruba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 34, {'name': 'Australia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 35, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 38, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 39, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 42, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 44, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 47, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 48, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 51, {'name': 'Azerbaijan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 52, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 53, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 54, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 55, {'name': 'Saint Lucia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 56, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 57, {'name': 'Bahrain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 58, {'name': 'Bangladesh'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 59, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 60, {'name': 'Belgium'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 61, {'name': 'Benin'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 62, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 63, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 64, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 65, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 66, {'name': 'Bhutan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 67, {'name': 'Bolivia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 68, {'name': 'Bosnia and Herzegovina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 69, {'name': 'Botswana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 70, {'name': 'Brazil'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 71, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 72, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 73, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 74, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 75, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 76, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 77, {'name': 'Brunei'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 78, {'name': 'Bulgaria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 79, {'name': 'Cambodia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 80, {'name': 'Cameroon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 81, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 82, {'name': 'Grenada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 83, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 84, {'name': 'Saint Vincent and the Grenadines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 85, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 86, {'name': 'Central African Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 87, {'name': 'Chad'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 88, {'name': 'Chile'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 89, {'name': 'France'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 90, {'name': 'Georgia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 91, {'name': 'Kazakhstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 92, {'name': 'Serbia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 93, {'name': 'Colombia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 94, {'name': 'Congo'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 95, {'name': 'Cuba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 96, {'name': "Côte d'Ivoire"}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 97, {'name': 'Denmark'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 98, {'name': 'Djibouti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 99, {'name': 'Dominica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 100, {'name': 'Dominican Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 101, {'name': 'Ecuador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 102, {'name': 'Egypt'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 103, {'name': 'El Salvador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 104, {'name': 'Estonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 105, {'name': 'Fiji'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 106, {'name': 'Finland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 107, {'name': 'French Guiana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 108, {'name': 'French Polynesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 109, {'name': 'Gabon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 110, {'name': 'Ghana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 111, {'name': 'Greece'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 112, {'name': 'Guam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 113, {'name': 'Guatemala'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 114, {'name': 'Guinea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 115, {'name': 'Guyana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 116, {'name': 'Haiti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 117, {'name': 'Honduras'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 118, {'name': 'Japan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 119, {'name': 'Kuwait'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 120, {'name': 'Portugal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 121, {'name': 'South Korea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 122, {'name': 'Taiwan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 123, {'name': 'Hungary'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 124, {'name': 'Iceland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 125, {'name': 'India'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 126, {'name': 'Iran'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 127, {'name': 'Italy'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 128, {'name': 'Jamaica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 129, {'name': 'Jordan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 130, {'name': 'Kenya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 131, {'name': 'Kyrgyzstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 132, {'name': 'Laos'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 133, {'name': 'Lebanon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 134, {'name': 'Lesotho'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 135, {'name': 'Libya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 136, {'name': 'Lithuania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 137, {'name': 'Macao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 138, {'name': 'Macedonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 139, {'name': 'Madagascar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 140, {'name': 'Malawi'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 141, {'name': 'Mali'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 142, {'name': 'Mexico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 143, {'name': 'Moldova'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 144, {'name': 'Monaco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 145, {'name': 'Mongolia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 146, {'name': 'Montenegro'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 147, {'name': 'Morocco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 148, {'name': 'Mozambique'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 149, {'name': 'Myanmar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 150, {'name': 'Namibia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 151, {'name': 'Nauru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 152, {'name': 'Nepal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 153, {'name': 'Nicaragua'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 154, {'name': 'Nigeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 155, {'name': 'Norfolk Island'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 156, {'name': 'Northern Mariana Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 157, {'name': 'Norway'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 158, {'name': 'Oman'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 159, {'name': 'Pakistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 160, {'name': 'Palestine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 161, {'name': 'Papua New Guinea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 162, {'name': 'Paraguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 163, {'name': 'Peru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 164, {'name': 'Philippines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 165, {'name': 'Poland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 166, {'name': 'Puerto Rico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 167, {'name': 'Qatar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 168, {'name': 'Romania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 169, {'name': 'Saint Martin (French part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 170, {'name': 'Saudi Arabia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 171, {'name': 'Senegal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 172, {'name': 'Sierra Leone'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 173, {'name': 'Sint Maarten (Dutch part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 174, {'name': 'Slovakia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 175, {'name': 'Slovenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 176, {'name': 'Spain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 177, {'name': 'Sri Lanka'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 178, {'name': 'Sudan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 179, {'name': 'Suriname'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 180, {'name': 'Syria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 181, {'name': 'Tajikistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 182, {'name': 'Tanzania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 183, {'name': 'Tonga'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 184, {'name': 'Trinidad and Tobago'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 185, {'name': 'Tunisia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 186, {'name': 'Turkey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 187, {'name': 'Turkmenistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 188, {'name': 'Uganda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 189, {'name': 'Dubai'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 190, {'name': 'Uzbekistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 191, {'name': 'Venezuela'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 192, {'name': 'Vietnam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 193, {'name': 'Yemen'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 194, {'name': 'Zambia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 195, {'name': 'Zimbabwe'})]

# %%
##similar to mini-proj, try a random target 
import random
random.seed(5104)
def unweighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'avg_betweenness':bet,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#try another function but this time with g.diameter having weight param 
#https://igraph.org/python/api/latest/igraph._igraph.GraphBase.html#diameter

random.seed(5104)
def weighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    pr = []
    auth = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #try pagerank 
        page = g.pagerank(directed=True, weights='weight')
        page = sum(page)/max(len(page),1)
        pr.append(page)
        
        #authority score normalised by default
        kleinberg = g.authority_score(weights='weight')
        kleinberg = sum(kleinberg)/max(len(kleinberg),1)
        auth.append(kleinberg)
        
        #try in-degree
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'avg_weighted_betweenness':bet,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'avg_PageRank':pr,
                       'avg_Authority':auth,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type1_unweighted = unweighted_Type1_random_delete(g)
df_type1_unweighted.head()
# Out:
#    nodes_removed  avg_betweenness  prop_removed  diameter  \
# 0              1        74.107692          0.01       4.0
# 1              2        73.984536          0.01       4.0
# 2              3        73.943005          0.02       4.0
# 3              4        73.947917          0.02       4.0
# 4              5        73.869110          0.03       4.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.470685                14.420513  0.073951          1.960455
# 1             -0.470699                14.474227  0.074609          1.959040
# 2             -0.469460                14.512953  0.075197          1.958686
# 3             -0.468696                14.526042  0.075656          1.958936
# 4             -0.469423                14.554974  0.076204          1.958101

# %%
df_type1_unweighted.tail()
# Out:
#      nodes_removed  avg_betweenness  prop_removed  diameter  \
# 191            192              0.0          0.98       0.0
# 192            193              0.0          0.98       0.0
# 193            194              0.0          0.99       0.0
# 194            195              0.0          0.99       0.0
# 195            196              0.0          1.00       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 191                   NaN                      0.0      0.0               NaN
# 192                   NaN                      0.0      0.0               NaN
# 193                   NaN                      0.0      0.0               NaN
# 194                   NaN                      0.0      0.0               NaN
# 195                   NaN                      0.0      NaN               NaN

# %%
df_type1_weighted = weighted_Type1_random_delete(g)
df_type1_weighted.head()
# Out:
#    nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 0              1          0.01      23.5                137.381474
# 1              2          0.01      23.5                135.948280
# 2              3          0.02      23.5                134.333279
# 3              4          0.02      23.5                133.320000
# 4              5          0.03      23.5                133.382297
#
#    assortativity_degree  avg_weighted_indegree   density  avg_PageRank  \
# 0             -0.469442            2838.284615  0.074504      0.005128
# 1             -0.468203            2850.811856  0.074344      0.005155
# 2             -0.466851            2843.453368  0.073881      0.005181
# 3             -0.466865            2857.734375  0.074083      0.005208
# 4             -0.465599            2872.562827  0.074642      0.005236
#
#    avg_Authority  average_path_len
# 0       0.008647          1.957730
# 1       0.008691          1.958658
# 2       0.008738          1.960452
# 3       0.008783          1.960213
# 4       0.008829          1.959997

# %%
df_type1_weighted.tail(15)
# Out:
#      nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 181            182          0.93      52.0                  2.428571
# 182            183          0.93      52.0                  2.153846
# 183            184          0.94      52.0                  1.750000
# 184            185          0.94      48.0                  1.272727
# 185            186          0.95      48.0                  1.400000
# 186            187          0.95      38.0                  0.666667
# 187            188          0.96      38.0                  0.750000
# 188            189          0.96      38.0                  0.857143
# 189            190          0.97      38.0                  1.000000
# 190            191          0.97    4148.0                  0.000000
# 191            192          0.98      92.0                  0.000000
# 192            193          0.98       0.0                  0.000000
# 193            194          0.99       0.0                  0.000000
# 194            195          0.99       0.0                  0.000000
# 195            196          1.00       NaN                  0.000000
#
#      assortativity_degree  avg_weighted_indegree   density  avg_PageRank  \
# 181             -0.487487             376.357143  0.107143      0.071429
# 182             -0.502386             405.230769  0.118343      0.076923
# 183             -0.454813             438.833333  0.131944      0.083333
# 184             -0.459361             478.363636  0.148760      0.090909
# 185             -0.459361             526.200000  0.180000      0.100000
# 186             -0.125000             482.222222  0.111111      0.111111
# 187             -0.125000             542.500000  0.140625      0.125000
# 188             -0.125000             620.000000  0.183673      0.142857
# 189             -0.125000             723.333333  0.250000      0.166667
# 190                   NaN             853.200000  0.120000      0.200000
# 191                   NaN              29.500000  0.125000      0.250000
# 192                   NaN               0.000000  0.000000      0.333333
# 193                   NaN               0.000000  0.000000      0.500000
# 194                   NaN               0.000000  0.000000      1.000000
# 195                   NaN               0.000000       NaN      0.000000
#
#      avg_Authority  average_path_len
# 181       0.072188          1.536585
# 182       0.077741          1.500000
# 183       0.084220          1.419355
# 184       0.091876          1.307692
# 185       0.101064          1.307692
# 186       0.111492          1.307692
# 187       0.125428          1.307692
# 188       0.143347          1.307692
# 189       0.167238          1.307692
# 190       0.200000          1.000000
# 191       0.250000          1.000000
# 192       1.000000               NaN
# 193       1.000000               NaN
# 194       1.000000               NaN
# 195       0.000000               NaN

# %% [markdown]
# ### Targeted attack

# %%
##try sort by indegree 
temp_df = pd.DataFrame({'Node_indice':g.vs.indices,
                         'Nodes':g.vs['name'],
                         'In_Degree':g.strength(mode='in',weights='weight')})

# %%
#sort by largest degree 
temp_df = temp_df.sort_values(by='In_Degree',ascending=False)

# %%
temp_df.head(50)
# Out:
#     Node_indice                     Nodes  In_Degree
# 3             3    British Virgin Islands   280925.0
# 15           15                    Panama    89885.0
# 18           18                Seychelles    31501.5
# 1             1                   Bahamas    31085.0
# 14           14                      Niue    18912.0
# 4             4            United Kingdom    16320.0
# 10           10                 Hong Kong    14145.0
# 17           17                     Samoa    12807.0
# 16           16                    Russia    10958.0
# 33           33          British Anguilla     6480.0
# 24           24                  Barbados     4722.0
# 21           21                   Bermuda     4662.0
# 5             5             United States     4337.0
# 37           37                    Cyprus     3465.0
# 11           11                   Ireland     3316.0
# 7             7            Cayman Islands     2926.5
# 22           22                     China     2598.0
# 13           13                    Nevada     2520.0
# 25           25                    Canada     1486.0
# 26           26     Saint Kitts and Nevis     1371.0
# 12           12                    Latvia     1299.0
# 50           50      United Arab Emirates      891.0
# 42           42                    Labuan      883.5
# 46           46                 Singapore      690.5
# 40           40               Isle of Man      582.0
# 8             8              Cook Islands      534.0
# 36           36                    Belize      436.0
# 41           41                    Jersey      426.0
# 43           43                Luxembourg      405.0
# 53           53                     Malta      390.0
# 75           75         State of Delaware      362.0
# 30           30               Switzerland      226.0
# 23           23       Antigua and Barbuda      214.0
# 45           45               Netherlands      173.0
# 59           59                 Mauritius      159.0
# 49           49                   Ukraine      158.0
# 9             9                Costa Rica      156.0
# 38           38            Czech Republic       87.0
# 48           48                    Sweden       84.0
# 63           63             Liechtenstein       84.0
# 19           19                   Uruguay       80.0
# 56           56                   Wyoming       74.0
# 52           52                 Gibraltar       66.0
# 35           35                   Austria       63.0
# 44           44                  Malaysia       60.5
# 29           29               New Zealand       59.0
# 83           83                  Guernsey       50.0
# 39           39                   Germany       45.0
# 72           72                   Curaçao       40.0
# 64           64  Turks and Caicos Islands       34.0

# %%
temp_df.tail(50)
# Out:
#      Node_indice                   Nodes  In_Degree
# 80            80                Cameroon        0.0
# 79            79                Cambodia        0.0
# 78            78                Bulgaria        0.0
# 77            77                  Brunei        0.0
# 70            70                  Brazil        0.0
# 68            68  Bosnia and Herzegovina        0.0
# 99            99                Dominica        0.0
# 67            67                 Bolivia        0.0
# 66            66                  Bhutan        0.0
# 61            61                   Benin        0.0
# 60            60                 Belgium        0.0
# 58            58              Bangladesh        0.0
# 57            57                 Bahrain        0.0
# 51            51              Azerbaijan        0.0
# 31            31                 Armenia        0.0
# 27            27               Argentina        0.0
# 20            20                  Angola        0.0
# 6              6                 Andorra        0.0
# 2              2                 Algeria        0.0
# 97            97                 Denmark        0.0
# 100          100      Dominican Republic        0.0
# 134          134                 Lesotho        0.0
# 116          116                   Haiti        0.0
# 133          133                 Lebanon        0.0
# 132          132                    Laos        0.0
# 131          131              Kyrgyzstan        0.0
# 130          130                   Kenya        0.0
# 129          129                  Jordan        0.0
# 128          128                 Jamaica        0.0
# 127          127                   Italy        0.0
# 126          126                    Iran        0.0
# 125          125                   India        0.0
# 124          124                 Iceland        0.0
# 123          123                 Hungary        0.0
# 117          117                Honduras        0.0
# 115          115                  Guyana        0.0
# 101          101                 Ecuador        0.0
# 114          114                  Guinea        0.0
# 113          113               Guatemala        0.0
# 112          112                    Guam        0.0
# 111          111                  Greece        0.0
# 110          110                   Ghana        0.0
# 109          109                   Gabon        0.0
# 108          108        French Polynesia        0.0
# 107          107           French Guiana        0.0
# 106          106                 Finland        0.0
# 105          105                    Fiji        0.0
# 103          103             El Salvador        0.0
# 102          102                   Egypt        0.0
# 195          195                Zimbabwe        0.0

# %%
#extract out by Node
order_of_del = temp_df['Nodes'].tolist()

# %%
order_of_del
# Out:
# ['British Virgin Islands',
#  'Panama',
#  'Seychelles',
#  'Bahamas',
#  'Niue',
#  'United Kingdom',
#  'Hong Kong',
#  'Samoa',
#  'Russia',
#  'British Anguilla',
#  'Barbados',
#  'Bermuda',
#  'United States',
#  'Cyprus',
#  'Ireland',
#  'Cayman Islands',
#  'China',
#  'Nevada',
#  'Canada',
#  'Saint Kitts and Nevis',
#  'Latvia',
#  'United Arab Emirates',
#  'Labuan',
#  'Singapore',
#  'Isle of Man',
#  'Cook Islands',
#  'Belize',
#  'Jersey',
#  'Luxembourg',
#  'Malta',
#  'State of Delaware',
#  'Switzerland',
#  'Antigua and Barbuda',
#  'Netherlands',
#  'Mauritius',
#  'Ukraine',
#  'Costa Rica',
#  'Czech Republic',
#  'Sweden',
#  'Liechtenstein',
#  'Uruguay',
#  'Wyoming',
#  'Gibraltar',
#  'Austria',
#  'Malaysia',
#  'New Zealand',
#  'Guernsey',
#  'Germany',
#  'Curaçao',
#  'Turks and Caicos Islands',
#  'Israel',
#  'Saint Vincent and the Grenadines',
#  'Belarus',
#  'South Africa',
#  'Saint Lucia',
#  'Croatia',
#  'Liberia',
#  'Vanuatu',
#  'Netherlands Antilles',
#  'Thailand',
#  'Grenada',
#  'Marshall Islands',
#  'Taiwan',
#  'Indonesia',
#  'Georgia',
#  'US Virgin Islands',
#  'Australia',
#  'Serbia',
#  'Dubai',
#  'Aruba',
#  'Mexico',
#  'Japan',
#  'Kuwait',
#  'France',
#  'Spain',
#  'Kazakhstan',
#  'Philippines',
#  'Estonia',
#  'Portugal',
#  'South Korea',
#  'Malawi',
#  'Papua New Guinea',
#  'Macedonia',
#  'Palestine',
#  'Pakistan',
#  'Oman',
#  'Madagascar',
#  'Norway',
#  'Northern Mariana Islands',
#  'Norfolk Island',
#  'Nigeria',
#  'Nicaragua',
#  'Mali',
#  'Paraguay',
#  'Moldova',
#  'Nepal',
#  'Nauru',
#  'Namibia',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Albania',
#  'Tanzania',
#  'Peru',
#  'Poland',
#  'Zambia',
#  'Yemen',
#  'Vietnam',
#  'Venezuela',
#  'Uzbekistan',
#  'Uganda',
#  'Turkmenistan',
#  'Turkey',
#  'Tunisia',
#  'Trinidad and Tobago',
#  'Tonga',
#  'Lithuania',
#  'Tajikistan',
#  'Syria',
#  'Suriname',
#  'Sudan',
#  'Sri Lanka',
#  'Slovenia',
#  'Slovakia',
#  'Sint Maarten (Dutch part)',
#  'Sierra Leone',
#  'Senegal',
#  'Saudi Arabia',
#  'Saint Martin (French part)',
#  'Romania',
#  'Qatar',
#  'Puerto Rico',
#  'Macao',
#  'Djibouti',
#  'Libya',
#  'Botswana',
#  "Côte d'Ivoire",
#  'Cuba',
#  'Congo',
#  'Colombia',
#  'Chile',
#  'Chad',
#  'Central African Republic',
#  'Cameroon',
#  'Cambodia',
#  'Bulgaria',
#  'Brunei',
#  'Brazil',
#  'Bosnia and Herzegovina',
#  'Dominica',
#  'Bolivia',
#  'Bhutan',
#  'Benin',
#  'Belgium',
#  'Bangladesh',
#  'Bahrain',
#  'Azerbaijan',
#  'Armenia',
#  'Argentina',
#  'Angola',
#  'Andorra',
#  'Algeria',
#  'Denmark',
#  'Dominican Republic',
#  'Lesotho',
#  'Haiti',
#  'Lebanon',
#  'Laos',
#  'Kyrgyzstan',
#  'Kenya',
#  'Jordan',
#  'Jamaica',
#  'Italy',
#  'Iran',
#  'India',
#  'Iceland',
#  'Hungary',
#  'Honduras',
#  'Guyana',
#  'Ecuador',
#  'Guinea',
#  'Guatemala',
#  'Guam',
#  'Greece',
#  'Ghana',
#  'Gabon',
#  'French Polynesia',
#  'French Guiana',
#  'Finland',
#  'Fiji',
#  'El Salvador',
#  'Egypt',
#  'Zimbabwe']

# %%
def unweighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %% [markdown]
# ## Trial on edgeID

# %%
#Weighted on diameter
def weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    pr = []
    auth = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #try pagerank 
        page = g.pagerank(directed=True, weights='weight')
        page = sum(page)/max(len(page),1)
        pr.append(page)
        #authority score normalised by default
        kleinberg = g.authority_score(weights='weight')
        kleinberg = sum(kleinberg)/max(len(kleinberg),1)
        auth.append(kleinberg)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'avg_PageRank':pr,
                       'avg_Authority':auth,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type2_unweighted = unweighted_Type2_targeted_del(g)
df_type2_unweighted.head()
# Out:
#    num_nodes_removed  prop_removed            node_removed  avg_betweenness  \
# 0                  1          0.01  British Virgin Islands        71.923077
# 1                  2          0.01                  Panama        69.654639
# 2                  3          0.02              Seychelles        67.290155
# 3                  4          0.02                 Bahamas        66.791667
# 4                  5          0.03                    Niue        66.120419
#
#    diameter  assortativity_degree  avg_unweighted_indegree   density  \
# 0       4.0             -0.452126                13.389744  0.068665
# 1       4.0             -0.444601                12.510309  0.064486
# 2       4.0             -0.449322                11.932642  0.061827
# 3       4.0             -0.453574                11.369792  0.059218
# 4       4.0             -0.456955                11.062827  0.057921
#
#    average_path_len
# 0          1.980358
# 1          1.989456
# 2          1.985805
# 3          1.997899
# 4          2.001745

# %%
df_type2_unweighted.tail()
# Out:
#      num_nodes_removed  prop_removed node_removed  avg_betweenness  diameter  \
# 191                192          0.98      Finland              0.0       0.0
# 192                193          0.98         Fiji              0.0       0.0
# 193                194          0.99  El Salvador              0.0       0.0
# 194                195          0.99        Egypt              0.0       0.0
# 195                196          1.00     Zimbabwe              0.0       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 191                   NaN                      0.0      0.0               NaN
# 192                   NaN                      0.0      0.0               NaN
# 193                   NaN                      0.0      0.0               NaN
# 194                   NaN                      0.0      0.0               NaN
# 195                   NaN                      0.0      NaN               NaN

# %%
df_type2_weighted = weighted_Type2_targeted_del(g)
df_type2_weighted.head(15)
# Out:
#     num_nodes_removed  prop_removed            node_removed  \
# 0                   1          0.01  British Virgin Islands
# 1                   2          0.01                  Panama
# 2                   3          0.02              Seychelles
# 3                   4          0.02                 Bahamas
# 4                   5          0.03                    Niue
# 5                   6          0.03          United Kingdom
# 6                   7          0.04               Hong Kong
# 7                   8          0.04                   Samoa
# 8                   9          0.05                  Russia
# 9                  10          0.05        British Anguilla
# 10                 11          0.06                Barbados
# 11                 12          0.06                 Bermuda
# 12                 13          0.07           United States
# 13                 14          0.07                  Cyprus
# 14                 15          0.08                 Ireland
#
#     avg_weighted_betweenness  diameter  assortativity_degree  \
# 0                 129.964080      17.0             -0.452126
# 1                 124.322810      17.0             -0.444601
# 2                 119.392408      17.0             -0.449322
# 3                 116.745495      17.0             -0.453574
# 4                 114.916335      17.0             -0.456955
# 5                 114.163654     135.0             -0.449271
# 6                 107.520361     357.0             -0.427684
# 7                 106.474707     357.0             -0.433746
# 8                 104.794011     357.0             -0.425701
# 9                 103.367399     357.0             -0.432080
# 10                 97.660127     135.0             -0.432755
# 11                 95.562103     136.0             -0.440840
# 12                 93.786067     245.0             -0.418790
# 13                 91.374941     245.0             -0.412669
# 14                 88.322086     245.0             -0.401226
#
#     avg_weighted_indegree   density  avg_PageRank  avg_Authority  \
# 0             1362.169231  0.068665      0.005128       0.009829
# 1              855.796392  0.064486      0.005155       0.023145
# 2              708.611399  0.061827      0.005181       0.031010
# 3              557.848958  0.059218      0.005208       0.029832
# 4              479.010471  0.057921      0.005236       0.027919
# 5              390.973684  0.053823      0.005263       0.020058
# 6              239.023810  0.049159      0.005291       0.020292
# 7              208.335106  0.047306      0.005319       0.017946
# 8              162.032086  0.043467      0.005348       0.028540
# 9              147.306452  0.042462      0.005376       0.027754
# 10             136.302703  0.040847      0.005405       0.028008
# 11             118.048913  0.038693      0.005435       0.028511
# 12              89.035519  0.034907      0.005464       0.027534
# 13              75.087912  0.031971      0.005495       0.024737
# 14              63.596685  0.029364      0.005525       0.038362
#
#     average_path_len
# 0           1.980358
# 1           1.989456
# 2           1.985805
# 3           1.997899
# 4           2.001745
# 5           2.025374
# 6           2.087336
# 7           2.096617
# 8           2.128360
# 9           2.132719
# 10          2.111579
# 11          2.125954
# 12          2.218426
# 13          2.242528
# 14          2.249669

# %%
df_type2_weighted.tail(15)
# Out:
#      num_nodes_removed  prop_removed      node_removed  \
# 181                182          0.93            Guyana
# 182                183          0.93           Ecuador
# 183                184          0.94            Guinea
# 184                185          0.94         Guatemala
# 185                186          0.95              Guam
# 186                187          0.95            Greece
# 187                188          0.96             Ghana
# 188                189          0.96             Gabon
# 189                190          0.97  French Polynesia
# 190                191          0.97     French Guiana
# 191                192          0.98           Finland
# 192                193          0.98              Fiji
# 193                194          0.99       El Salvador
# 194                195          0.99             Egypt
# 195                196          1.00          Zimbabwe
#
#      avg_weighted_betweenness  diameter  assortativity_degree  \
# 181                       0.0       0.0                   NaN
# 182                       0.0       0.0                   NaN
# 183                       0.0       0.0                   NaN
# 184                       0.0       0.0                   NaN
# 185                       0.0       0.0                   NaN
# 186                       0.0       0.0                   NaN
# 187                       0.0       0.0                   NaN
# 188                       0.0       0.0                   NaN
# 189                       0.0       0.0                   NaN
# 190                       0.0       0.0                   NaN
# 191                       0.0       0.0                   NaN
# 192                       0.0       0.0                   NaN
# 193                       0.0       0.0                   NaN
# 194                       0.0       0.0                   NaN
# 195                       0.0       NaN                   NaN
#
#      avg_weighted_indegree  density  avg_PageRank  avg_Authority  \
# 181                    0.0      0.0      0.071429            1.0
# 182                    0.0      0.0      0.076923            1.0
# 183                    0.0      0.0      0.083333            1.0
# 184                    0.0      0.0      0.090909            1.0
# 185                    0.0      0.0      0.100000            1.0
# 186                    0.0      0.0      0.111111            1.0
# 187                    0.0      0.0      0.125000            1.0
# 188                    0.0      0.0      0.142857            1.0
# 189                    0.0      0.0      0.166667            1.0
# 190                    0.0      0.0      0.200000            1.0
# 191                    0.0      0.0      0.250000            1.0
# 192                    0.0      0.0      0.333333            1.0
# 193                    0.0      0.0      0.500000            1.0
# 194                    0.0      0.0      1.000000            1.0
# 195                    0.0      NaN      0.000000            0.0
#
#      average_path_len
# 181               NaN
# 182               NaN
# 183               NaN
# 184               NaN
# 185               NaN
# 186               NaN
# 187               NaN
# 188               NaN
# 189               NaN
# 190               NaN
# 191               NaN
# 192               NaN
# 193               NaN
# 194               NaN
# 195               NaN

# %% [markdown]
# #### Unweighted

# %%
## Commented out to not confuse; use the weighted one below 

#Try plotting unweighted
#fig, ax = plt.subplots(1,2,figsize=(14,6),sharey=True)
#ax2_1 = ax[0].twinx()
#ax[0].plot('prop_removed','diameter',data=df_type1_unweighted,ls='--',color='darkblue')
#ax[0].plot('prop_removed','density',data=df_type1_unweighted,ls='--',color='darkviolet')
#ax[0].plot('prop_removed','avg_betweenness',data=df_type1_unweighted,ls='--',color='darkgreen')
#ax2_1.plot('prop_removed','avg_unweighted_indegree',data=df_type1_unweighted,ls='--',color='darkred')
#ax[0].plot('prop_removed','assortativity_degree',data=df_type1_unweighted,ls='--',color='darkturquoise')
#ax[0].plot('prop_removed','average_path_len',data=df_type1_unweighted,ls='--',color='darkorange')
#ax[0].legend(loc='upper right')
#ax[0].set_xlabel('Proportion of nodes removed')
#ax[0].set_title('Random deletion')
#ax2_1.tick_params('y',colors='darkred')
#ax2_1.set_ylabel('Avg inDegree')
#ax2_1.legend(loc='upper left')

#ax2_2 = ax[1].twinx()
#ax[1].plot('prop_removed','diameter',data=df_type2_unweighted,ls='--',color='blue')
#ax[1].plot('prop_removed','density',data=df_type2_unweighted,ls='--',color='violet')
#ax[1].plot('prop_removed','avg_betweenness',data=df_type2_unweighted,ls='--',color='green')
#ax2_2.plot('prop_removed','avg_unweighted_indegree',data=df_type2_unweighted,ls='--',color='red')
#ax[1].plot('prop_removed','assortativity_degree',data=df_type2_unweighted,ls='--',color='turquoise')
#ax[1].plot('prop_removed','average_path_len',data=df_type2_unweighted,ls='--',color='orange')
#ax[1].legend(loc='upper right')
#ax[1].set_xlabel('Proportion of nodes removed')
#ax[1].set_title('Targeted deletion')
#ax2_2.tick_params('y',colors='darkred')
#ax2_2.set_ylabel('Avg inDegree')
#ax2_2.legend(loc='upper left')
#plt.show()

# %% [markdown]
# #### Weighted

# %% [markdown]
# Weighted has to set y-limit because of huge range

# %%
#Same but weighted
#Don't share y axis for type2
fig, ax = plt.subplots(2,2,figsize=(18,12),sharey=False)

#Random attack LHS graphs

ax[0,1].plot('prop_removed','diameter',data=df_type1_weighted,ls='-',color='darkblue')
ax[0,0].plot('prop_removed','density',data=df_type1_weighted,ls='-',color='darkviolet')
#remove assortativity degree, replace with pagerank
ax[0,0].plot('prop_removed','avg_PageRank',data=df_type1_weighted,ls='-',color='darkturquoise')
#add in authority score
ax[0,0].plot('prop_removed','avg_Authority',data=df_type1_weighted,ls='-',color='slategray')
ax[0,0].plot('prop_removed','average_path_len',data=df_type1_weighted,ls='-',color='darkorange')
ax[0,0].legend(loc='upper right')
ax[0,0].set_xlabel('Proportion of nodes removed')
ax[0,0].set_title('Random deletion')

ax2_1 = ax[0,0].twinx()
ax2_1.plot('prop_removed','avg_weighted_indegree',data=df_type1_weighted,ls='-',color='darkred')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

#Random attack RHS Graphs - Betweenness & Diameter
ax[0,1].set_title('Random deletion - Betweenness & Diameter')
ax[0,1].legend(loc='upper left')

ax_bet_rand = ax[0,1].twinx()
ax_bet_rand.plot('prop_removed','avg_weighted_betweenness',data=df_type1_weighted,ls='--',color='darkgreen')
ax_bet_rand.tick_params('y',colors='darkgreen')
ax_bet_rand.set_ylabel('Avg_weighted_betweenness')
ax_bet_rand.legend(loc='upper right')


#Targeted attack LHS Graphs

ax[1,1].plot('prop_removed','diameter',data=df_type2_weighted,ls='-',color='blue')
ax[1,0].plot('prop_removed','density',data=df_type2_weighted,ls='-',color='violet')
#remove assortativity degree, replace with pagerank
ax[1,0].plot('prop_removed','avg_PageRank',data=df_type2_weighted,ls='-',color='turquoise')
# add in Authority
ax[1,0].plot('prop_removed','avg_Authority',data=df_type2_weighted,ls='-',color='lightslategray')
ax[1,0].plot('prop_removed','average_path_len',data=df_type2_weighted,ls='-',color='orange')
ax[1,0].legend(loc='upper right')
ax[1,0].set_xlabel('Proportion of nodes removed')
ax[1,0].set_title('Targeted deletion')

ax2_2 = ax[1,0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=df_type2_weighted,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1,1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1,1].legend(loc='upper left')

ax_bet_tar = ax[1,1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=df_type2_weighted,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.savefig('Directed_all_nodes.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Attack on Edges

# %%
g.get_eid(3,4)
# Out:
# 374

# %%
list(g.es)
# Out:
# [igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 0, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 2, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'weight': 52.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'weight': 82.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 6, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'weight': 0.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 9, {'weight': 18.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'weight': 48.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'weight': 24.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'weight': 558.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'weight': 18.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'weight': 144.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 19, {'weight': 30.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 20, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'weight': 23.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 23, {'weight': 16.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'weight': 16.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 27, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 28, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 29, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 30, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 31, {'weight': 30.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 32, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 34, {'weight': 1.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 35, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 36, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 38, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 39, {'weight': 46.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 42, {'weight': 189.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 44, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 45, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'weight': 19.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 47, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 48, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 49, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 51, {'weight': 294.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 52, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 53, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 54, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 55, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 56, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 57, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 58, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 59, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 60, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 61, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 62, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 63, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 64, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 65, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 66, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 67, {'weight': 38.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 68, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 69, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 70, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 71, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 72, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 73, {'weight': 84.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 74, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 75, {'weight': 646.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 76, {'weight': 17.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 77, {'weight': 15.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 78, {'weight': 22.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 79, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 80, {'weight': 31.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 81, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 82, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 83, {'weight': 165.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 84, {'weight': 31.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 85, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 86, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 87, {'weight': 0.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 88, {'weight': 9.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 89, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 90, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 91, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 92, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 93, {'weight': 89.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 94, {'weight': 107.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 95, {'weight': 13.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 96, {'weight': 1.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 97, {'weight': 22.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 98, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 99, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 100, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 101, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 102, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 103, {'weight': 151.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 104, {'weight': 35.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 105, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 106, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 107, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 108, {'weight': 37.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 109, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 110, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 111, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 112, {'weight': 9.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 113, {'weight': 28.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 114, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 115, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 116, {'weight': 1.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 117, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 118, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 119, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 120, {'weight': 36.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 121, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 122, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 123, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 124, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 125, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 126, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 127, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 128, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 129, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 130, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 131, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 132, {'weight': 100.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 133, {'weight': 18.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 134, {'weight': 90.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 135, {'weight': 3645.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 136, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 137, {'weight': 46.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 138, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 139, {'weight': 2.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 140, {'weight': 18.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 141, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 142, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 143, {'weight': 52.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 144, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 145, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 146, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 147, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 148, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 149, {'weight': 582.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 150, {'weight': 116.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 151, {'weight': 4521.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 152, {'weight': 25.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 153, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 154, {'weight': 1.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 155, {'weight': 54.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 156, {'weight': 216.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 157, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 158, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 159, {'weight': 40.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 160, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 161, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 162, {'weight': 30.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 163, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 164, {'weight': 34.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 165, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 166, {'weight': 9.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 167, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 168, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 169, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 170, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 171, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 172, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 173, {'weight': 33.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 174, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 175, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 176, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 177, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 178, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 179, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 180, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 181, {'weight': 16.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 182, {'weight': 39.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 183, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 184, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 185, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 186, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 187, {'weight': 37.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 188, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 189, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 190, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 191, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 192, {'weight': 47.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 193, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 194, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 195, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 196, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 197, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 198, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 199, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 200, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 201, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 202, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 203, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 204, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 205, {'weight': 16.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 206, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 207, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 208, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 209, {'weight': 94.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 210, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 211, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 212, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 213, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 214, {'weight': 13.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 215, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 216, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 217, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 218, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 219, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 220, {'weight': 53.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 221, {'weight': 16.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 222, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 223, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 224, {'weight': 11.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 225, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 226, {'weight': 18.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 227, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 228, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 229, {'weight': 500.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 230, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 231, {'weight': 38.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 232, {'weight': 414.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 233, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 234, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 235, {'weight': 11.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 236, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 237, {'weight': 118.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 238, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 239, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 240, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 241, {'weight': 456.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 242, {'weight': 850.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 243, {'weight': 15.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 244, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 245, {'weight': 90.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 246, {'weight': 350.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 247, {'weight': 22.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 248, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 249, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 250, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 251, {'weight': 42.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 252, {'weight': 74.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 253, {'weight': 360.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 254, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 255, {'weight': 34.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 256, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 257, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 258, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 259, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 260, {'weight': 29.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 261, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 262, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 263, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 264, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 265, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 266, {'weight': 11.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 267, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 268, {'weight': 54.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 269, {'weight': 20.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 270, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 271, {'weight': 1.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 272, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 273, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 274, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 275, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 276, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 277, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 278, {'weight': 29.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 279, {'weight': 47.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 280, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 281, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 282, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 283, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 284, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 285, {'weight': 182.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 286, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 287, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 288, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 289, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 290, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 291, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 292, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 293, {'weight': 66.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 294, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 295, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 296, {'weight': 28.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 297, {'weight': 986.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 298, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 299, {'weight': 42.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 300, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 301, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 302, {'weight': 11.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 303, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 304, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 305, {'weight': 264.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 306, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 307, {'weight': 182.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 308, {'weight': 1044.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 309, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 310, {'weight': 86.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 311, {'weight': 159.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 312, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 313, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 314, {'weight': 25.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 315, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 316, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 317, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 318, {'weight': 14.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 319, {'weight': 42.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 320, {'weight': 16.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 321, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 322, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 323, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 324, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 325, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 326, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 327, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 328, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 329, {'weight': 290.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 330, {'weight': 2106.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 331, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 332, {'weight': 9.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 333, {'weight': 26.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 334, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 335, {'weight': 96.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 336, {'weight': 20.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 337, {'weight': 174.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 338, {'weight': 152.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 339, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 340, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 341, {'weight': 198.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 342, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 343, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 344, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 345, {'weight': 896.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 346, {'weight': 184.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 347, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 348, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 349, {'weight': 27.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 350, {'weight': 0.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 351, {'weight': 70.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 352, {'weight': 20.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 353, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 354, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 355, {'weight': 1.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 356, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 357, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 358, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 359, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 360, {'weight': 513.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 361, {'weight': 608.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 362, {'weight': 79.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 363, {'weight': 4.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 364, {'weight': 96.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 365, {'weight': 37.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 366, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 367, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 368, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 369, {'weight': 11.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 370, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 371, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 372, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 373, {'weight': 66.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 374, {'weight': 918.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 375, {'weight': 248.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 376, {'weight': 33.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 377, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 378, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 379, {'weight': 11.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 380, {'weight': 9.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 381, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 382, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 383, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 384, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 385, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 386, {'weight': 49.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 387, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 388, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 389, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 390, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 391, {'weight': 11.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 392, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 393, {'weight': 44.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 394, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 395, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 396, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 397, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 398, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 399, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 400, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 401, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 402, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 403, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 404, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 405, {'weight': 72.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 406, {'weight': 264.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 407, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 408, {'weight': 158.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 409, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 410, {'weight': 875.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 411, {'weight': 129.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 412, {'weight': 29.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 413, {'weight': 4.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 414, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 415, {'weight': 22.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 416, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 417, {'weight': 124.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 418, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 419, {'weight': 29.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 420, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 421, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 422, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 423, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 424, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 425, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 426, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 427, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 428, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 429, {'weight': 62.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 430, {'weight': 201.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 431, {'weight': 95.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 432, {'weight': 9.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 433, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 434, {'weight': 47.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 435, {'weight': 14.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 436, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 437, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 438, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 439, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 440, {'weight': 117.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 441, {'weight': 38.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 442, {'weight': 9.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 443, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 444, {'weight': 86.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 445, {'weight': 226.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 446, {'weight': 42.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 447, {'weight': 2446.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 448, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 449, {'weight': 15.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 450, {'weight': 72.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 451, {'weight': 31.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 452, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 453, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 454, {'weight': 18.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 455, {'weight': 259.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 456, {'weight': 21.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 457, {'weight': 16.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 458, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 459, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 460, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 461, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 462, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 463, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 464, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 465, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 466, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 467, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 468, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 469, {'weight': 134.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 470, {'weight': 71.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 471, {'weight': 195.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 472, {'weight': 24.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 473, {'weight': 1709.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 474, {'weight': 17.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 475, {'weight': 13.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 476, {'weight': 232.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 477, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 478, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 479, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 480, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 481, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 482, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 483, {'weight': 98.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 484, {'weight': 82.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 485, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 486, {'weight': 20.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 487, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 488, {'weight': 28.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 489, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 490, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 491, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 492, {'weight': 93.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 493, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 494, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 495, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 496, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 497, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 498, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 499, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 500, {'weight': 173.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 501, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 502, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 503, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 504, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 505, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 506, {'weight': 26.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 507, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 508, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 509, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 510, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 511, {'weight': 23.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 512, {'weight': 154.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 513, {'weight': 296.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 514, {'weight': 11138.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 515, {'weight': 150.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 516, {'weight': 296.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 517, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 518, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 519, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 520, {'weight': 396.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 521, {'weight': 13.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 522, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 523, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 524, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 525, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 526, {'weight': 2046.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 527, {'weight': 397.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 528, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 529, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 530, {'weight': 48.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 531, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 532, {'weight': 0.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 533, {'weight': 165.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 534, {'weight': 47.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 535, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 536, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 537, {'weight': 18.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 538, {'weight': 14.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 539, {'weight': 18.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 540, {'weight': 24.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 541, {'weight': 670.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 542, {'weight': 1470.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 543, {'weight': 135.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 544, {'weight': 748.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 545, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 546, {'weight': 1486.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 547, {'weight': 74.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 548, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 549, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 550, {'weight': 25.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 551, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 552, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 553, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 554, {'weight': 17.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 555, {'weight': 101.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 556, {'weight': 2035.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 557, {'weight': 566.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 558, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 559, {'weight': 44.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 560, {'weight': 38.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 561, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 562, {'weight': 118.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 563, {'weight': 541.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 564, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 565, {'weight': 84.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 566, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 567, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 568, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 569, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 570, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 571, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 572, {'weight': 20.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 573, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 574, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 575, {'weight': 2715.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 576, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 577, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 578, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 579, {'weight': 36.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 580, {'weight': 104.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 581, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 582, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 583, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 584, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 585, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 586, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 587, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 588, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 589, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 590, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 591, {'weight': 317.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 592, {'weight': 11.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 593, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 594, {'weight': 21.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 595, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 596, {'weight': 90.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 597, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 598, {'weight': 23.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 599, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 600, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 601, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 602, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 603, {'weight': 34.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 604, {'weight': 60.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 605, {'weight': 13.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 606, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 607, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 608, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 609, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 610, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 611, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 612, {'weight': 106.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 613, {'weight': 24.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 614, {'weight': 64.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 615, {'weight': 22.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 616, {'weight': 288.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 617, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 618, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 619, {'weight': 11.0}),
# ...
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 794, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 795, {'weight': 14.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 796, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 797, {'weight': 391.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 798, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 799, {'weight': 228.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 800, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 801, {'weight': 1295.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 802, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 803, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 804, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 805, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 806, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 807, {'weight': 136.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 808, {'weight': 28.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 809, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 810, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 811, {'weight': 68.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 812, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 813, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 814, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 815, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 816, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 817, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 818, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 819, {'weight': 1.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 820, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 821, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 822, {'weight': 64.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 823, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 824, {'weight': 71.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 825, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 826, {'weight': 14.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 827, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 828, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 829, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 830, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 831, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 832, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 833, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 834, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 835, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 836, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 837, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 838, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 839, {'weight': 46.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 840, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 841, {'weight': 50.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 842, {'weight': 20.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 843, {'weight': 408.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 844, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 845, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 846, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 847, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 848, {'weight': 8.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 849, {'weight': 34.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 850, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 851, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 852, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 853, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 854, {'weight': 0.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 855, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 856, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 857, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 858, {'weight': 36.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 859, {'weight': 168.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 860, {'weight': 35.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 861, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 862, {'weight': 7.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 863, {'weight': 33.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 864, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 865, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 866, {'weight': 38.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 867, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 868, {'weight': 40.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 869, {'weight': 16.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 870, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 871, {'weight': 14.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 872, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 873, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 874, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 875, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 876, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 877, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 878, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 879, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 880, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 881, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 882, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 883, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 884, {'weight': 0.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 885, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 886, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 887, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 888, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 889, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 890, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 891, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 892, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 893, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 894, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 895, {'weight': 222.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 896, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 897, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 898, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 899, {'weight': 19.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 900, {'weight': 53.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 901, {'weight': 11.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 902, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 903, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 904, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 905, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 906, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 907, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 908, {'weight': 273.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 909, {'weight': 31.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 910, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 911, {'weight': 1.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 912, {'weight': 23.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 913, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 914, {'weight': 37.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 915, {'weight': 20.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 916, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 917, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 918, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 919, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 920, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 921, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 922, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 923, {'weight': 300.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 924, {'weight': 16.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 925, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 926, {'weight': 3211.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 927, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 928, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 929, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 930, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 931, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 932, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 933, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 934, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 935, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 936, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 937, {'weight': 56.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 938, {'weight': 396.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 939, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 940, {'weight': 28.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 941, {'weight': 128.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 942, {'weight': 1.5}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 943, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 944, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 945, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 946, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 947, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 948, {'weight': 14.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 949, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 950, {'weight': 172.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 951, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 952, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 953, {'weight': 7.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 954, {'weight': 3.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 955, {'weight': 10.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 956, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 957, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 958, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 959, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 960, {'weight': 273.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 961, {'weight': 13.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 962, {'weight': 43.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 963, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 964, {'weight': 12.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 965, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 966, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 967, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 968, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 969, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 970, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 971, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 972, {'weight': 78.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 973, {'weight': 46.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 974, {'weight': 370.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 975, {'weight': 16.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 976, {'weight': 280.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 977, {'weight': 1602.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 978, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 979, {'weight': 32.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 980, {'weight': 60.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 981, {'weight': 3008.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 982, {'weight': 26.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 983, {'weight': 6.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 984, {'weight': 54.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 985, {'weight': 9562.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 986, {'weight': 5.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 987, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 988, {'weight': 9.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 989, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 990, {'weight': 8.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 991, {'weight': 2.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 992, {'weight': 25.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 993, {'weight': 4.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 994, {'weight': 44.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 995, {'weight': 16.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 996, {'weight': 1.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 997, {'weight': 604.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 998, {'weight': 1423.0}),
#  igraph.Edge(<igraph.Graph object at 0x7fae1ab27d60>, 999, {'weight': 24.0}),
#  ...]

# %%
#because the g.es only shows the edge ID, we need to get the vertex source and target
##sv = source vertex 
##st = source target 
sv = []
st = []
for edge in g.es:
    source_vertex_id = edge.source
    target_vertex_id = edge.target
    source_vertex = g.vs[source_vertex_id]
    sv.append(source_vertex)
    target_vertex = g.vs[target_vertex_id]
    st.append(target_vertex)

# %%
##get name of source vertices. sv and st each is an igraph object so need to slice them to get the names

sv_name = []
for i in range(len(sv)):
    name = sv[i]['name']
    sv_name.append(name)
    
st_name = []
for i in range(len(st)):
    target_name = st[i]['name']
    st_name.append(target_name)

# %%
## view to see if it works
st_name
# Out:
# ['Bahamas',
#  'British Virgin Islands',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'Cook Islands',
#  'Costa Rica',
#  'Hong Kong',
#  'Ireland',
#  'Latvia',
#  'Nevada',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Samoa',
#  'Seychelles',
#  'United Kingdom',
#  'Uruguay',
#  'Bermuda',
#  'British Virgin Islands',
#  'China',
#  'Barbados',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Hong Kong',
#  'Ireland',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'United Kingdom',
#  'United States',
#  'Antigua and Barbuda',
#  'Bahamas',
#  'Barbados',
#  'Belarus',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'Costa Rica',
#  'Hong Kong',
#  'Ireland',
#  'Nevada',
#  'New Zealand',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Seychelles',
#  'Switzerland',
#  'United Kingdom',
#  'United States',
#  'British Virgin Islands',
#  'China',
#  'Hong Kong',
#  'Panama',
#  'Russia',
#  'United Kingdom',
#  'United States',
#  'Barbados',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Panama',
#  'Austria',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cook Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Hong Kong',
#  'Ireland',
#  'Isle of Man',
#  'Jersey',
#  'Labuan',
#  'Latvia',
#  'Luxembourg',
#  'Malaysia',
#  'Netherlands',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'South Africa',
#  'Sweden',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'Cyprus',
#  'Hong Kong',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'British Virgin Islands',
#  'Canada',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Netherlands',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'United Kingdom',
#  'United States',
#  'Barbados',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cook Islands',
#  'Costa Rica',
#  'Cyprus',
#  'Gibraltar',
#  'Hong Kong',
#  'Ireland',
#  'Latvia',
#  'Luxembourg',
#  'Malta',
#  'Netherlands Antilles',
#  'Nevada',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Wyoming',
#  'Bermuda',
#  'British Virgin Islands',
#  'Hong Kong',
#  'Panama',
#  'Russia',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Bermuda',
#  'British Virgin Islands',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Latvia',
#  'Russia',
#  'United Kingdom',
#  'Bahamas',
#  'Bermuda',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Panama',
#  'Russia',
#  'Singapore',
#  'United Kingdom',
#  'Austria',
#  'British Virgin Islands',
#  'China',
#  'Hong Kong',
#  'Ireland',
#  'Luxembourg',
#  'Mauritius',
#  'Panama',
#  'Russia',
#  'Singapore',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'Barbados',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Isle of Man',
#  'Latvia',
#  'Luxembourg',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Australia',
#  'Bahamas',
#  'Barbados',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Mauritius',
#  'Netherlands',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'United Kingdom',
#  'United States',
#  'Wyoming',
#  'British Virgin Islands',
#  'Bahamas',
#  'Barbados',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cook Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Hong Kong',
#  'Ireland',
#  'Jersey',
#  'Latvia',
#  'Liberia',
#  'Liechtenstein',
#  'Netherlands',
#  'Netherlands Antilles',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'South Africa',
#  'Sweden',
#  'Turks and Caicos Islands',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Vanuatu',
#  'British Virgin Islands',
#  'Hong Kong',
#  'British Virgin Islands',
#  'Hong Kong',
#  'Panama',
#  'British Virgin Islands',
#  'China',
#  'Hong Kong',
#  'British Virgin Islands',
#  'Panama',
#  'Seychelles',
#  'United Kingdom',
#  'Bahamas',
#  'Barbados',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Isle of Man',
#  'Nevada',
#  'New Zealand',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Wyoming',
#  'Barbados',
#  'British Anguilla',
#  'British Virgin Islands',
#  'China',
#  'Hong Kong',
#  'Ireland',
#  'Panama',
#  'Russia',
#  'United Kingdom',
#  'Antigua and Barbuda',
#  'Austria',
#  'Bahamas',
#  'Barbados',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'British Anguilla',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cook Islands',
#  'Croatia',
#  'Curaçao',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Gibraltar',
#  'Hong Kong',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Jersey',
#  'Labuan',
#  'Latvia',
#  'Luxembourg',
#  'Malaysia',
#  'Malta',
#  'Marshall Islands',
#  'Mauritius',
#  'Netherlands',
#  'Nevada',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'South Africa',
#  'State of Delaware',
#  'Sweden',
#  'Switzerland',
#  'Thailand',
#  'Turks and Caicos Islands',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'British Virgin Islands',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Seychelles',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'British Virgin Islands',
#  'China',
#  'Hong Kong',
#  'Ireland',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Seychelles',
#  'United Kingdom',
#  'United States',
#  'British Virgin Islands',
#  'China',
#  'Hong Kong',
#  'Ireland',
#  'Panama',
#  'Russia',
#  'United Kingdom',
#  'Seychelles',
#  'Antigua and Barbuda',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'China',
#  'Cook Islands',
#  'Curaçao',
#  'Cyprus',
#  'Gibraltar',
#  'Hong Kong',
#  'Indonesia',
#  'Ireland',
#  'Isle of Man',
#  'Jersey',
#  'Labuan',
#  'Latvia',
#  'Luxembourg',
#  'Malaysia',
#  'Mauritius',
#  'Netherlands',
#  'Nevada',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'South Africa',
#  'Switzerland',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Antigua and Barbuda',
#  'Aruba',
#  'Bahamas',
#  'Barbados',
#  'Bermuda',
#  'British Virgin Islands',
#  'Canada',
#  'China',
#  'Cook Islands',
#  'Cyprus',
#  'Gibraltar',
#  'Grenada',
#  'Guernsey',
#  'Hong Kong',
#  'Ireland',
#  'Isle of Man',
#  'Jersey',
#  'Latvia',
#  'Liberia',
#  'Liechtenstein',
#  'Luxembourg',
#  'Malta',
#  'Marshall Islands',
#  'Netherlands',
#  'Netherlands Antilles',
#  'New Zealand',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'State of Delaware',
#  'Sweden',
#  'Switzerland',
#  'Turks and Caicos Islands',
#  'US Virgin Islands',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'Panama',
#  'Bahamas',
#  'Barbados',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'China',
#  'Costa Rica',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Nevada',
#  'Panama',
#  'Russia',
#  'Seychelles',
#  'United Kingdom',
#  'United States',
#  'Wyoming',
#  'Antigua and Barbuda',
#  'Austria',
#  'Bahamas',
#  'Barbados',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'Cook Islands',
#  'Croatia',
#  'Curaçao',
#  'Cyprus',
#  'Czech Republic',
#  'France',
#  'Georgia',
#  'Germany',
#  'Gibraltar',
#  'Hong Kong',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Jersey',
#  'Kazakhstan',
#  'Labuan',
#  'Latvia',
#  'Luxembourg',
#  'Malaysia',
#  'Malta',
#  'Mauritius',
#  'Netherlands',
#  'Nevada',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Serbia',
#  'Seychelles',
#  'Singapore',
#  'South Africa',
#  'Sweden',
#  'Switzerland',
#  'Thailand',
#  'Turks and Caicos Islands',
#  'US Virgin Islands',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Vanuatu',
#  'Bahamas',
#  'Belize',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'Costa Rica',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Latvia',
#  'Luxembourg',
#  'Malta',
#  'Nevada',
#  'New Zealand',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'British Virgin Islands',
#  'Ireland',
#  'Russia',
#  'Singapore',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Bermuda',
#  'British Virgin Islands',
#  'Canada',
#  'China',
#  'Cyprus',
#  'Gibraltar',
#  'Hong Kong',
#  'Indonesia',
#  'Ireland',
#  'Jersey',
#  'Latvia',
#  'Netherlands',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'Switzerland',
#  'Turks and Caicos Islands',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'China',
#  'Hong Kong',
#  'Isle of Man',
#  'Nevada',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'United Kingdom',
#  'Barbados',
#  'British Virgin Islands',
#  'Cyprus',
#  'Ireland',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Barbados',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'Panama',
#  'Barbados',
#  'Bermuda',
#  'British Virgin Islands',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Jersey',
#  'Panama',
#  'Russia',
#  'Seychelles',
#  'Singapore',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Antigua and Barbuda',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cook Islands',
#  'Croatia',
#  'Czech Republic',
#  'Germany',
#  'Gibraltar',
#  'Hong Kong',
#  'Ireland',
#  'Isle of Man',
#  'Jersey',
#  'Labuan',
#  'Latvia',
#  'Luxembourg',
#  'Malaysia',
#  'Mauritius',
#  'Netherlands',
#  'Nevada',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'Switzerland',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'British Virgin Islands',
#  'Canada',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Isle of Man',
#  'Netherlands',
#  'Panama',
#  'Russia',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'United Kingdom',
#  'British Virgin Islands',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Nevada',
#  'Niue',
#  'Panama',
#  'Samoa',
#  'United Kingdom',
#  'Bahamas',
#  'Barbados',
#  'Bermuda',
#  'British Virgin Islands',
#  'Hong Kong',
#  'Latvia',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Seychelles',
#  'Ukraine',
#  'United Kingdom',
#  'United States',
#  'British Virgin Islands',
#  'Canada',
#  'China',
#  'Panama',
#  'Barbados',
#  'British Virgin Islands',
#  'Hong Kong',
#  'Israel',
#  'Jersey',
#  'Panama',
#  'Bahamas',
#  'Barbados',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Panama',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'Costa Rica',
#  'Hong Kong',
#  'Ireland',
#  'Nevada',
#  'New Zealand',
#  'Niue',
#  'Panama',
#  'Samoa',
#  'Seychelles',
#  'United Kingdom',
#  'Uruguay',
#  'Bahamas',
#  'Barbados',
#  'Bermuda',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Panama',
#  'Russia',
#  'Seychelles',
#  'United Kingdom',
#  'Bahamas',
#  'Barbados',
#  'British Anguilla',
#  'British Virgin Islands',
#  'China',
#  'Hong Kong',
#  'Nevada',
#  'Niue',
#  'Panama',
#  'Seychelles',
#  'Bahamas',
#  'British Anguilla',
#  'British Virgin Islands',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Isle of Man',
#  'Malta',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Samoa',
#  'Seychelles',
#  'British Virgin Islands',
#  'Canada',
#  'Cook Islands',
#  'Hong Kong',
#  'Ireland',
#  'Latvia',
#  'Russia',
#  'Singapore',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'Belize',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Seychelles',
#  'Singapore',
#  'United Kingdom',
#  'United States',
#  'Antigua and Barbuda',
#  'Bahamas',
#  'Barbados',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cook Islands',
#  'Cyprus',
#  'Hong Kong',
#  'Indonesia',
#  'Ireland',
#  'Isle of Man',
#  'Jersey',
#  'Labuan',
#  'Latvia',
#  'Malaysia',
#  'Nevada',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'Guernsey',
#  'British Virgin Islands',
#  'Hong Kong',
#  'Latvia',
#  'Panama',
#  'Russia',
#  'United Kingdom',
#  'United States',
#  'British Virgin Islands',
#  'Panama',
#  'Russia',
#  'British Anguilla',
#  'British Virgin Islands',
#  'China',
#  'Cook Islands',
#  'Ireland',
#  'Panama',
#  'Russia',
#  'United Arab Emirates',
#  'United Kingdom',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Isle of Man',
#  'Jersey',
#  'Latvia',
#  'Luxembourg',
#  'Mauritius',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Hong Kong',
#  'Russia',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Hong Kong',
#  'Ireland',
#  'Isle of Man',
#  'Jersey',
#  'Luxembourg',
#  'Malta',
#  'Nevada',
#  'Niue',
#  'Panama',
#  'Russia',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'Switzerland',
#  'Thailand',
#  'Ukraine',
#  'United Kingdom',
#  'United States',
#  'Bahamas',
#  'Bermuda',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cyprus',
#  'Hong Kong',
#  'Ireland',
#  'Jersey',
#  'Liberia',
#  'Malta',
#  'Panama',
#  'Russia',
#  'Seychelles',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Barbados',
#  'British Virgin Islands',
#  'Panama',
#  'Saint Kitts and Nevis',
#  'British Virgin Islands',
#  'United States',
#  'Bahamas',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'Niue',
#  'Panama',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Seychelles',
#  'Bahamas',
#  'Barbados',
#  'Bermuda',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'China',
#  'Cook Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Hong Kong',
#  'Ireland',
#  'Isle of Man',
#  'Jersey',
#  'Luxembourg',
#  'Niue',
#  'Panama',
#  'Russia',
#  ...]

# %%
st
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 9, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 19, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 23, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 28, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 9, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 29, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 30, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 35, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 38, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 39, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 42, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 44, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 47, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 48, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 9, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 52, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 53, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 54, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 55, {'name': 'Saint Lucia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 19, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 56, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 35, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 59, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 34, {'name': 'Australia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 59, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 56, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 38, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 62, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 63, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 54, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 47, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 48, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 64, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 65, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 29, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 19, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 56, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 23, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 35, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 28, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 71, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 72, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 38, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 39, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 52, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 73, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 42, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 44, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 53, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 74, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 59, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 47, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 75, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 48, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 30, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 76, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 64, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 23, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 72, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 52, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 81, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 42, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 44, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 59, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 47, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 30, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 23, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 32, {'name': 'Aruba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 52, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 82, {'name': 'Grenada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 83, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 62, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 63, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 53, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 74, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 54, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 29, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 84, {'name': 'Saint Vincent and the Grenadines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 75, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 48, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 30, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 64, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 85, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 9, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 56, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 23, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 35, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 28, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 71, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 72, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 38, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 89, {'name': 'France'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 90, {'name': 'Georgia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 39, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 52, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 73, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 91, {'name': 'Kazakhstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 42, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 44, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 53, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 59, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 92, {'name': 'Serbia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 47, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 48, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 30, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 76, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 64, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 85, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 65, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
# ...
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 23, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 81, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 42, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 44, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 83, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 59, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 53, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 30, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 76, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 62, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 53, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 38, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fae1ab27d60>, 16, {'name': 'Russia'}),
#  ...]

# %%
## new df with edges
edge_df = pd.DataFrame({'Edge_indice':g.es.indices,
                         'Edges_weight':g.es['weight'],
                         'Vertex_source':sv_name,
                         'Vertex_target':st_name})

# %%
##sort by descending weight
edge_df = edge_df.sort_values(by='Edges_weight',ascending=False)

# %%
edge_df.head(15)
# Out:
#       Edge_indice  Edges_weight         Vertex_source           Vertex_target
# 1028         1028       65366.5             Hong Kong  British Virgin Islands
# 2351         2351       39766.5           Switzerland  British Virgin Islands
# 2369         2369       23216.0           Switzerland                  Panama
# 1322         1322       21362.5                Jersey  British Virgin Islands
# 2395         2395       15735.0                Taiwan  British Virgin Islands
# 2643         2643       11652.0        United Kingdom  British Virgin Islands
# 2171         2171       11524.5             Singapore  British Virgin Islands
# 1514         1514       11169.0            Luxembourg                  Panama
# 514           514       11138.0                 China  British Virgin Islands
# 1852         1852        9789.5                Panama  British Virgin Islands
# 985           985        9562.0              Guernsey  British Virgin Islands
# 1065         1065        7776.5             Hong Kong              Seychelles
# 2606         2606        7374.0  United Arab Emirates  British Virgin Islands
# 2689         2689        6425.0         United States  British Virgin Islands
# 2000         2000        6292.5                Russia  British Virgin Islands

# %%
jersey_df = edge_df.loc[edge_df['Vertex_source']=='Jersey']

# %%
jersey_df.head(15)
# Out:
#       Edge_indice  Edges_weight Vertex_source           Vertex_target
# 1322         1322       21362.5        Jersey  British Virgin Islands
# 1337         1337        4272.0        Jersey                  Panama
# 1317         1317        2488.0        Jersey                 Bahamas
# 1336         1336         688.0        Jersey                    Niue
# 1328         1328         181.0        Jersey               Hong Kong
# 1318         1318          88.0        Jersey                Barbados
# 1345         1345          60.0        Jersey          United Kingdom
# 1341         1341          43.0        Jersey              Seychelles
# 1330         1330          38.0        Jersey             Isle of Man
# 1340         1340          37.0        Jersey                   Samoa
# 1338         1338          33.0        Jersey                  Russia
# 1320         1320          26.0        Jersey                 Bermuda
# 1324         1324          22.0        Jersey          Cayman Islands
# 1325         1325          20.0        Jersey                   China
# 1346         1346          18.0        Jersey           United States

# %%
jersey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 1322 to 1343
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Edge_indice    31 non-null     int64
#  1   Edges_weight   31 non-null     float64
#  2   Vertex_source  31 non-null     object
#  3   Vertex_target  31 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.2+ KB

# %%
edge_deletelist = edge_df['Edge_indice'].tolist()

# %%
len(edge_deletelist)
# Out:
# 2840

# %%
#Weighted on diameter
def Edges_weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    pr = []
    auth = []
    for i in range(len(g.es)):
        try:
            g.delete_edges(edge_deletelist[i])
        except:
            continue
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #try pagerank 
        page = g.pagerank(directed=True, weights='weight')
        page = sum(page)/max(len(page),1)
        pr.append(page)
        #authority score normalised by default
        kleinberg = g.authority_score(weights='weight')
        kleinberg = sum(kleinberg)/max(len(kleinberg),1)
        auth.append(kleinberg)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/len(edge_deletelist),2) #2840 is ttotal rows in df
        prop_removed.append(prop)
        node_removed.append(edge_deletelist[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'avg_PageRank':pr,
                       'avg_Authority':auth,
                       'average_path_len':apl})
    
    return(df)

# %%
testtest= Edges_weighted_Type2_targeted_del(g)

# %%
testtest
# Out:
#       num_nodes_removed  prop_removed  node_removed  avg_weighted_betweenness  \
# 0                     1           0.0          1028                137.451807
# 1                     2           0.0          2351                137.451807
# 2                     3           0.0          2369                137.482774
# 3                     4           0.0          1322                137.482774
# 4                     5           0.0          2395                137.482774
# ...                 ...           ...           ...                       ...
# 1774               2828           1.0           884                173.490476
# 1775               2831           1.0           854                173.495578
# 1776               2832           1.0           532                173.495578
# 1777               2834           1.0            87                173.495578
# 1778               2839           1.0           350                173.495578
#
#       diameter  assortativity_degree  avg_weighted_indegree   density  \
# 0         23.5             -0.472317            2490.408163  0.073901
# 1         23.5             -0.472256            2490.362245  0.073875
# 2         23.5             -0.472133            2490.352041  0.073849
# 3         23.5             -0.472036            2490.331633  0.073823
# 4         23.5             -0.471962            2490.295918  0.073797
# ...        ...                   ...                    ...       ...
# 1774     210.0             -0.432190             946.066327  0.027723
# 1775     210.0             -0.433000             946.056122  0.027697
# 1776     210.0             -0.432562             945.989796  0.027671
# 1777     210.0             -0.431389             945.775510  0.027645
# 1778     210.0             -0.431755             945.632653  0.027619
#
#       avg_PageRank  avg_Authority  average_path_len
# 0         0.005102       0.009869          1.959011
# 1         0.005102       0.009869          1.959077
# 2         0.005102       0.009869          1.959143
# 3         0.005102       0.009868          1.959209
# 4         0.005102       0.009868          1.959275
# ...            ...            ...               ...
# 1774      0.005102       0.006215          2.419191
# 1775      0.005102       0.006215          2.419275
# 1776      0.005102       0.006215          2.419856
# 1777      0.005102       0.006215          2.420686
# 1778      0.005102       0.006214          2.421350
#
# [1779 rows x 11 columns]

# %%
fig, ax = plt.subplots(1,2,figsize=(14,8),sharey=False)

#Targeted attack LHS Graphs

    
ax[0].plot('prop_removed','density',data=testtest,ls='-',color='violet')
#remove assortativity degree, replace with pagerank
ax[0].plot('prop_removed','avg_PageRank',data=testtest,ls='-',color='turquoise')
# add in Authority
ax[0].plot('prop_removed','avg_Authority',data=testtest,ls='-',color='lightslategray')
ax[0].plot('prop_removed','average_path_len',data=testtest,ls='-',color='orange')
ax[0].legend(loc='upper right')
ax[0].set_xlabel('Proportion of edges removed')
ax[0].set_title('Targeted deletion')

ax2_2 = ax[0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=testtest,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1].plot('prop_removed','diameter',data=testtest,ls='-',color='blue')
ax[1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1].legend(loc='upper left')
    
    
ax_bet_tar = ax[1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=testtest,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.savefig('Directed_all_edges.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Edge chord diagram

# %%
## top 10 
top10 = pd.DataFrame({'source':edge_df['Vertex_source'],
                     'target':edge_df['Vertex_target'],
                     'weight':edge_df['Edges_weight']})

# %%
top10 = top10[:10]
top10
# Out:
#               source                  target   weight
# 1028       Hong Kong  British Virgin Islands  65366.5
# 2351     Switzerland  British Virgin Islands  39766.5
# 2369     Switzerland                  Panama  23216.0
# 1322          Jersey  British Virgin Islands  21362.5
# 2395          Taiwan  British Virgin Islands  15735.0
# 2643  United Kingdom  British Virgin Islands  11652.0
# 2171       Singapore  British Virgin Islands  11524.5
# 1514      Luxembourg                  Panama  11169.0
# 514            China  British Virgin Islands  11138.0
# 1852          Panama  British Virgin Islands   9789.5

# %%
## recreate graph
g2 = ig.Graph.TupleList(top10.itertuples(index=False), directed=True, edge_attrs={'weight': "weight"})

# %%
# Define colors used for visualization
colors = ['blue', 'yellow', 'green','purple', 'pink', 'orange', 'lightcoral', 'plum', 'darkgreen', 'darkblue', 'rosybrown',
         'crimson', 'steelblue', 'khaki', 'moccasin', 'orangered', 'fuchsia', 'thistle', 'salmon', 'chocolate', 'lightseagreen',
         'springgreen', 'darkseagreen', 'deeppink', 'mediumvioletred','olive']

# %%
##plot chord 
#try top 10 by edge weight
visual_style = {}

vertex_colors = []

for i in range(len(top10)):
    vertex_colors.append(colors[i])
    
# Set bbox and margin
visual_style["bbox"] = (1000,1000)
visual_style["margin"] = 17

# Set vertex colours
visual_style["vertex_color"] = vertex_colors

# Set edge width
visual_style["edge_width"] = np.log(g2.es['weight']) + 1

# Set edge color
visual_style["edge_color"] = "rgba(1,1,1,0.1)" 

# Set vertex size
visual_style["vertex_size"] = 15

# Set vertex label size
visual_style["vertex_label_size"] = 20

# Set vertex label color
visual_style["vertex_label_color"] = 'red'

# Don't curve the edges
visual_style["edge_curved"] = False

# Set the layout
my_layout = g2.layout_circle()
visual_style["layout"] = my_layout

# Plot the graph
ig.plot(g2, 'top10_edge.png' ,vertex_label=g2.vs['name'], **visual_style)

# %% [markdown]
# ### Pagerank

# %%
pr = pd.read_csv('../top_10_pagerank_edgelist.csv')

# %%
pr.head()
# Out:
#   node_start                node_end  weight
# 0    Bahamas                Barbados   100.0
# 1    Bahamas                 Bermuda    18.0
# 2    Bahamas  British Virgin Islands  3645.5
# 3    Bahamas               Hong Kong    52.0
# 4    Bahamas                    Niue   116.0

# %%
##try sort by indegree 
#pagerank_temp_df = pd.DataFrame({'Node_indice':g.vs.indices,
#                         'Nodes':g.vs['name'],
#                         'PageRank': g.pagerank(directed=True, weights='weight')})

# %%
#sort by descending 
#pagerank_temp_df = pagerank_temp_df.sort_values(by='PageRank',ascending=False)

# %%
#pagerank_temp_df

# %%
#pagerank_top10 = pagerank_temp_df[:10]

# %%
#pagerank_top10

# %%
#edge_df.loc[edge_df['Edge_indice']==329]

# %%
#v = g.vs[3]
#hedges = g.incident(3)
#hedges

# %%
g3 = ig.Graph.TupleList(pr.itertuples(index=False), directed=True, edge_attrs={'weight': "weight"})

# %%
ig.plot(g3)

# %%
##Commented out possibly some error in code, Susan has pushed the top10 pagerank
## recreate graph
#g3 = ig.Graph.TupleList(pagerank_top10.itertuples(index=False), directed=True, edge_attrs={'weight': "weight"})


##plot chord 
#try top 10 by edge weight
#visual_style = {}

#vertex_colors = []

#for i in range(len(pr)):
    #vertex_colors.append(colors[pr[i]])
    
# Set bbox and margin
#visual_style["bbox"] = (1000,1000)
#visual_style["margin"] = 17

# Set vertex colours
#visual_style["vertex_color"] = vertex_colors

# Set edge width
#visual_style["edge_width"] = np.log(g3.es['weight']) + 1

# Set edge color
#visual_style["edge_color"] = "rgba(1,1,1,0.1)" 

# Set vertex size
#visual_style["vertex_size"] = 15

# Set vertex label size
#visual_style["vertex_label_size"] = 20

# Set vertex label color
#visual_style["vertex_label_color"] = 'red'

# Don't curve the edges
#visual_style["edge_curved"] = False

# Set the layout
#my_layout = g3.layout_circle()
#visual_style["layout"] = my_layout

# Plot the graph
#ig.plot(g3, 'top10_pagerank.png' ,vertex_label=g3.vs['name'], **visual_style)
